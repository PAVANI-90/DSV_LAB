# %%
# Question 1 : Create a pandas series named sales containing the values 120,150,180,210.
import pandas as pd
sales = pd.Series([120, 150, 180, 210])
print(sales)
# Out:
# 0    120
# 1    150
# 2    180
# 3    210
# dtype: int64

# %%
# Question 2
#For the Series below, write the command that displays only the stored data values.
#marks = Series([72, 81, 69, 90])

from pandas import Series

marks = Series([72, 81, 69, 90])

print(marks.values)
# Out:
# [72 81 69 90]

# %%
# Question 3
from pandas import Series

marks = Series([72, 81, 69, 90])

print(marks.index)
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
# Question 4
from pandas import Series

temperature = Series([28, 31, 30, 29], index=['Mon', 'Tue', 'Wed', 'Thu'])

print(temperature)
# Out:
# Mon    28
# Tue    31
# Wed    30
# Thu    29
# dtype: int64

# %%
# Question 5
from pandas import Series

population = Series([35, 42, 31], index=['Delhi', 'Mumbai', 'Jaipur'])

print(population['Jaipur'])
# Out:
# 31

# %%
# Question 6
from pandas import Series

score = Series([35, 68, 44, 79, 52])

print(score[score > 50])
# Out:
# 1    68
# 3    79
# 4    52
# dtype: int64

# %%
# Question 7
from pandas import Series

subjects = Series([76, 83, 91], index=['Physics', 'Chemistry', 'Maths'])

print('Chemistry' in subjects.index)
# Out:
# True

# %%
# Question 8
from pandas import Series

marks = Series([72, 81, 69, 90])

d = marks.to_dict()

print(d)
# Out:
# {0: 72, 1: 81, 2: 69, 3: 90}

# %%
# Question 9
from pandas import Series

prices = {'Pen': 10, 'Notebook': 55, 'Bag': 700}

price_series = Series(prices)

print(price_series)
# Out:
# Pen          10
# Notebook     55
# Bag         700
# dtype: int64

# %%
# Question 10
from pandas import Series

prices = {'Pen': 10, 'Notebook': 55, 'Bag': 700}
s = Series(prices)


print(s) # keys will become the index of this question
# Out:
# Pen          10
# Notebook     55
# Bag         700
# dtype: int64

# %%
# Question 11
from pandas import Series

data = {'A': 10, 'B': 20, 'C': 30}

s = Series(data, index=['A', 'B', 'C', 'D'])

print(s)
# Out:
# A    10.0
# B    20.0
# C    30.0
# D     NaN
# dtype: float64

# %%
# Question 12
from pandas import Series

data = {'A': 10, 'B': 20, 'C': 30}

s = Series(data, index=['A', 'B', 'C', 'D'])

print(s.isnull())
# Out:
# A    False
# B    False
# C    False
# D     True
# dtype: bool

# %%
# Question 13
from pandas import Series

data = {'A': 10, 'B': 20, 'C': 30}

s = Series(data, index=['A', 'B', 'C', 'D'])

print(s.notnull())
# Out:
# A     True
# B     True
# C     True
# D    False
# dtype: bool

# %%
# Question 14
from pandas import Series

sales = Series([120, 150, 180, 210])

sales.name = "Monthly Sales"

print(sales)
# Out:
# 0    120
# 1    150
# 2    180
# 3    210
# Name: Monthly Sales, dtype: int64

# %%
# Question 15
from pandas import Series

sales = Series([120, 150, 180, 210],
               index=['Mon', 'Tue', 'Wed', 'Thu'])

sales.index.name = "Month"

print(sales)
# Out:
# Month
# Mon    120
# Tue    150
# Wed    180
# Thu    210
# dtype: int64

# %%
# Question 16
from pandas import Series

s = Series([18, 45, 27, 61], index=['P', 'Q', 'R', 'S'])

print(s[s > 30])
# Out:
# Q    45
# S    61
# dtype: int64

# %%
# Question 17
from pandas import Series

s = Series([500, 600, 700], index=['East', 'West', 'North'])

print('West' in s)
print(500 in s)
# Out:
# True
# False

# %%
# Question 18
from pandas import Series

city_data = {'Delhi': 80, 'Pune': 65, 'Kochi': 70}

s = Series(city_data, index=['Delhi', 'Kochi', 'Pune', 'Chennai'])

print(s)
# Out:
# Delhi      80.0
# Kochi      70.0
# Pune       65.0
# Chennai     NaN
# dtype: float64

# %%
# Question 19
from pandas import Series
import pandas as pd

s = Series({'W': 5, 'X': 10, 'Y': 15}, index=['W', 'X', 'Y', 'Z'])

print(pd.isnull(s))
# Out:
# W    False
# X    False
# Y    False
# Z     True
# dtype: bool

# %%
# Question 20
from pandas import Series
import pandas as pd

s = Series({'W': 5, 'X': 10, 'Y': 15}, index=['W', 'X', 'Y', 'Z'])

print(pd.notnull(s))
# Out:
# W     True
# X     True
# Y     True
# Z    False
# dtype: bool

# %%
# Question 21
from pandas import Series

s1 = Series([10, 20, 30], index=['A', 'B', 'C'])
s2 = Series([1, 2, 3], index=['C', 'A', 'B'])
result = s1 + s2


print(result)
# Out:
# A    12
# B    23
# C    31
# dtype: int64

# %%
# Question 22
from pandas import Series

s1 = Series({'A': 12, 'B': 18})
s2 = Series({'B': 5, 'C': 9})

print(s1 + s2)
# Pandas performs addition by matching index labels, not by position. If a label is missing in either Series, the result for that label becomes NaN.
# Iska reason Pandas ka index alignment hai. Pandas position se add nahi karta, label (index) se add karta hai.
# Out:
# A     NaN
# B    23.0
# C     NaN
# dtype: float64

# %%
# Question 23
from pandas import Series

stock = Series([25, 40, 18], index=['Item1', 'Item2', 'Item3'])

stock_dict = stock.to_dict()

stock2 = Series(stock_dict)

print(stock_dict)
print(stock2)
# Out:
# {'Item1': 25, 'Item2': 40, 'Item3': 18}
# Item1    25
# Item2    40
# Item3    18
# dtype: int64

# %%
# Question 24
from pandas import Series

marks = {'Maths': 88, 'Science': 74, 'English': 69, 'History': 81}

s = Series(marks, index=['History', 'English', 'Science', 'Maths'])

print(s)

print("\nValues greater than 70:")
print(s[s > 70])
# Out:
# History    81
# English    69
# Science    74
# Maths      88
# dtype: int64
#
# Values greater than 70:
# History    81
# Science    74
# Maths      88
# dtype: int64

# %%
# Question 25
from pandas import Series

rev = Series([100, 200, 300], index=['A', 'B', 'C'])

rev.name = "Revenue"
rev.index.name = "Branch"

print(rev)
# Out:
# Branch
# A    100
# B    200
# C    300
# Name: Revenue, dtype: int64

# %%
# Question 26
from pandas import Series

north = Series({'Jan': 40, 'Feb': 55, 'Mar': 60})
south = Series({'Feb': 20, 'Mar': 25, 'Apr': 30})

total = north + south

print(total)
# Out:
# Apr     NaN
# Feb    75.0
# Jan     NaN
# Mar    85.0
# dtype: float64

# %%
# Question 27
from pandas import Series
import pandas as pd

d = {'Red': 12, 'Blue': 18, 'Green': 24}

labels = ['Green', 'Red', 'Yellow', 'Blue']

result = Series(d, index=labels)

print(result)
# Out:
# Green     24.0
# Red       12.0
# Yellow     NaN
# Blue      18.0
# dtype: float64

# %%
# Question 28
from pandas import Series

s = Series([90, 75, 82], index=['Ravi', 'Aman', 'Neha'])

d = s.to_dict()

s2 = Series(d)

print(s2)
# Out:
# Ravi    90
# Aman    75
# Neha    82
# dtype: int64

# %%
# Question 29
from pandas import Series

sales = Series([450, 620, 800, 300],
               index=['Pen', 'Notebook', 'Bag', 'Pencil'])

print(sales.values)
print(sales.index)

print(sales['Bag'])

print(sales[sales > 500])

print('Notebook' in sales.index)

sales_dict = sales.to_dict()
print(sales_dict)
# Out:
# [450 620 800 300]
# Index(['Pen', 'Notebook', 'Bag', 'Pencil'], dtype='object')
# 800
# Notebook    620
# Bag         800
# dtype: int64
# True
# {'Pen': 450, 'Notebook': 620, 'Bag': 800, 'Pencil': 300}

# %%
# Question 30
from pandas import Series
import pandas as pd

data = {'A': 15, 'B': 35, 'C': 25}

s = Series(data, index=['C', 'A', 'D', 'B'])

s.name = 'Observations'
s.index.name = 'Category'

print(s)
# Out:
# Category
# C    25.0
# A    15.0
# D     NaN
# B    35.0
# Name: Observations, dtype: float64
