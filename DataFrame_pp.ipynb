# %%
#Question 1
#Create a DataFrame named student_df from a dictionary containing the columns Name, Age, and City for four students.
import pandas as pd

data = {
    "Name": ["Aman", "Priya", "Rahul", "Sneha"],
    "Age": [20, 21, 19, 22],
    "City": ["Delhi", "Mumbai", "Lucknow", "Jaipur"]
}

student_df = pd.DataFrame(data)

print(student_df)
# Out:
#     Name  Age     City
# 0   Aman   20    Delhi
# 1  Priya   21   Mumbai
# 2  Rahul   19  Lucknow
# 3  Sneha   22   Jaipur

# %%
# Question 2
#Display the complete student_df DataFrame.
import pandas as pd

# Create a dictionary
data = {
    "Name": ["Aman", "Priya", "Rahul", "Sneha"],
    "Age": [20, 21, 19, 22],
    "City": ["Delhi", "Mumbai", "Lucknow", "Jaipur"]
}

# Create DataFrame
student_df = pd.DataFrame(data)

# Display the complete DataFrame
print(student_df)
# Out:
#     Name  Age     City
# 0   Aman   20    Delhi
# 1  Priya   21   Mumbai
# 2  Rahul   19  Lucknow
# 3  Sneha   22   Jaipur

# %%
# Question 3
# Write code to display the column names of student_df.
import pandas as pd

data = {
    "Name": ["Aman", "Priya", "Rahul", "Sneha"],
    "Age": [20, 21, 19, 22],
    "City": ["Delhi", "Mumbai", "Lucknow", "Jaipur"]
}

student_df = pd.DataFrame(data)

# Display column names
print(student_df.columns)
# Out:
# Index(['Name', 'Age', 'City'], dtype='object')

# %%
# Question 4
# Retrieve the Name column from student_df.
import pandas as pd

data = {
    "Name": ["Aman", "Priya", "Rahul", "Sneha"],
    "Age": [20, 21, 19, 22],
    "City": ["Delhi", "Mumbai", "Lucknow", "Jaipur"]
}

student_df = pd.DataFrame(data)

# Retrieve the Name column
print(student_df["Name"])
# Out:
# 0     Aman
# 1    Priya
# 2    Rahul
# 3    Sneha
# Name: Name, dtype: object

# %%
# Question 5
# Retrieve the City column from student_df using square-bracket notation.
import pandas as pd

data = {
    "Name": ["Aman", "Priya", "Rahul", "Sneha"],
    "Age": [20, 21, 19, 22],
    "City": ["Delhi", "Mumbai", "Lucknow", "Jaipur"]
}

student_df = pd.DataFrame(data)

print(student_df["City"])
# Out:
# 0      Delhi
# 1     Mumbai
# 2    Lucknow
# 3     Jaipur
# Name: City, dtype: object

# %%
# Question 6
# Create a new DataFrame from student_df containing only the columns Name and City.
from pandas import DataFrame

data = {
    "Name": ["Aman", "Priya", "Rahul", "Sneha"],
    "City": ["Delhi", "Mumbai", "Lucknow", "Jaipur"]
}

student_df = DataFrame(data)

new_df = student_df[["Name", "City"]]

print(new_df)
# Out:
#     Name     City
# 0   Aman    Delhi
# 1  Priya   Mumbai
# 2  Rahul  Lucknow
# 3  Sneha   Jaipur

# %%
# Question 7
# Create a DataFrame named book_df from a dictionary of equal-length lists containing Book, Author, and Price.
from pandas import DataFrame

data = {
    "Book": ["Python", "Java", "C++", "Data Science"],
    "Author": ["John", "James", "Robert", "Alice"],
    "Price": [450, 550, 600, 700]
}

book_df = DataFrame(data)

print(book_df)
# Out:
#            Book  Author  Price
# 0        Python    John    450
# 1          Java   James    550
# 2           C++  Robert    600
# 3  Data Science   Alice    700

# %%
# Question 8
#Add a new column named Publisher to book_df and assign the same publisher name to every row.
from pandas import DataFrame

data = {
    "Book": ["Python", "Java", "C++", "Data Science"],
    "Author": ["John", "James", "Robert", "Alice"],
    "Price": [450, 550, 600, 700]
}

book_df = DataFrame(data)

book_df["Publisher"] = "ABC Publications"

print(book_df)
# Out:
#            Book  Author  Price         Publisher
# 0        Python    John    450  ABC Publications
# 1          Java   James    550  ABC Publications
# 2           C++  Robert    600  ABC Publications
# 3  Data Science   Alice    700  ABC Publications

# %%
# Question 9
# Create a five-row DataFrame and assign the values generated by np.arange(5) to a new column named SerialNo.
from pandas import DataFrame
import numpy as np

data = {
    "Name": ["Aman", "Priya", "Rahul", "Sneha", "Riya"],
    "Age": [20, 21, 19, 22, 20]
}

student_df = DataFrame(data)

student_df["SerialNo"] = np.arange(5)

print(student_df)
# Out:
#     Name  Age  SerialNo
# 0   Aman   20         0
# 1  Priya   21         1
# 2  Rahul   19         2
# 3  Sneha   22         3
# 4   Riya   20         4

# %%
# Question 10
#Delete the SerialNo column from the DataFrame created in Question 9.
from pandas import DataFrame
import numpy as np

data = {
    "Name": ["Aman", "Priya", "Rahul", "Sneha", "Riya"],
    "Age": [20, 21, 19, 22, 20]
}

student_df = DataFrame(data)

student_df["SerialNo"] = np.arange(5)

student_df = student_df.drop("SerialNo", axis=1)

print(student_df)
# Out:
#     Name  Age
# 0   Aman   20
# 1  Priya   21
# 2  Rahul   19
# 3  Sneha   22
# 4   Riya   20

# %%
# Question 11
#Create a DataFrame named movie_df containing the columns Movie, Year, and Rating.
from pandas import DataFrame
data = {"Movie" : ["PK" , "Bahubali" , "Dangal"] , "Year" : [2014,2015,2016] , "Rating" : [8.0,8.1,8.3]}
movie_df = DataFrame(data)
print(movie_df)
# Out:
#       Movie  Year  Rating
# 0        PK  2014     8.0
# 1  Bahubali  2015     8.1
# 2    Dangal  2016     8.3

# %%
# Question 12
#From movie_df, create another DataFrame containing the columns Movie, Rating, and a new requested column named Director that is not present in the original DataFrame.
from pandas import DataFrame

data = {
    "Movie": ["3 Idiots", "Dangal", "PK", "Bahubali"],
    "Year": [2009, 2016, 2014, 2015],
    "Rating": [8.4, 8.3, 8.1, 8.0]
}

movie_df = DataFrame(data)

new_df = DataFrame(movie_df, columns=["Movie", "Rating", "Director"])

print(new_df)
# Out:
#       Movie  Rating  Director
# 0  3 Idiots     8.4       NaN
# 1    Dangal     8.3       NaN
# 2        PK     8.1       NaN
# 3  Bahubali     8.0       NaN

# %%
# Question 13 (series question)
#Create a Series containing two city names at indexes 0 and 3.
from pandas import Series

city = Series(["Delhi", "Mumbai"], index=[0, 3])

print(city)
# Out:
# 0     Delhi
# 3    Mumbai
# dtype: object

# %%
# Question 14
#Assign the Series from Question 13 to a new column named Branch in a four-row DataFrame.
from pandas import Series
from pandas import DataFrame

data = {
    "Name": ["Aman", "Priya", "Rahul", "Sneha"],
    "Age": [20, 21, 19, 22]
}

student_df = DataFrame(data)

city = Series(["Delhi", "Mumbai"], index=[0, 3])

student_df["Branch"] = city

print(student_df)
# Out:
#     Name  Age  Branch
# 0   Aman   20   Delhi
# 1  Priya   21     NaN
# 2  Rahul   19     NaN
# 3  Sneha   22  Mumbai

# %%
# Question 15
#Copy a small table from a spreadsheet or webpage and write code to read it into a DataFrame named copied_df using the clipboard-reading method covered in class.
from pandas import read_clipboard

copied_df = read_clipboard()

print(copied_df)
# Out:
# ---------------------------------------------------------------------------
# PyperclipException                        Traceback (most recent call last)
# /tmp/ipykernel_710/321856709.py in <cell line: 0>()
#       2 from pandas import read_clipboard
#       3
# ----> 4 copied_df = read_clipboard()
#       5
#       6 print(copied_df)
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/clipboards.py in read_clipboard(sep, dtype_backend, **kwargs)
#      84     from pandas.io.parsers import read_csv
#      85
# ---> 86     text = clipboard_get()
#      87
#      88     # Try to decode (if needed, as "text" might already be a string here).
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/clipboard/__init__.py in lazy_load_stub_paste()
#     679     global copy, paste
#     680     copy, paste = determine_clipboard()
# --> 681     return paste()
#     682
#     683
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/clipboard/__init__.py in __call__(self, *args, **kwargs)
# ...

# %%
# Question 16
#Create a five-row DataFrame named employee_df with columns Employee, Department, and Experience. Display only Employee and Experience in a new DataFrame.
from pandas import DataFrame

data = {
    "Employee": ["Aman", "Priya", "Rahul", "Sneha", "Riya"],
    "Department": ["HR", "IT", "Finance", "Sales", "Marketing"],
    "Experience": [2, 4, 3, 5, 1]
}

employee_df = DataFrame(data)

new_df = employee_df[["Employee", "Experience"]]

print(new_df)
# Out:
#   Employee  Experience
# 0     Aman           2
# 1    Priya           4
# 2    Rahul           3
# 3    Sneha           5
# 4     Riya           1

# %%
# Question 17
#Using employee_df, retrieve the Department column using one-column access and then display all column names.
from pandas import DataFrame

data = {
    "Employee": ["Aman", "Priya", "Rahul", "Sneha", "Riya"],
    "Department": ["HR", "IT", "Finance", "Sales", "Marketing"],
    "Experience": [2, 4, 3, 5, 1]
}

employee_df = DataFrame(data)

print(employee_df["Department"])

print(employee_df.columns)
# Out:
# 0           HR
# 1           IT
# 2      Finance
# 3        Sales
# 4    Marketing
# Name: Department, dtype: object
# Index(['Employee', 'Department', 'Experience'], dtype='object')

# %%
# Question 18
#Add a new column named Office to employee_df and assign 'Head Office' to every row. Then display the updated DataFrame.
from pandas import DataFrame
data = {
    "Employee": ["Aman", "Priya", "Rahul", "Sneha", "Riya"],
    "Department": ["HR", "IT", "Finance", "Sales", "Marketing"],
    "Experience": [2, 4, 3, 5, 1]
}

employee_df = DataFrame(data)

employee_df["Office"] = "Head Office"

print(employee_df)
# Out:
#   Employee Department  Experience       Office
# 0     Aman         HR           2  Head Office
# 1    Priya         IT           4  Head Office
# 2    Rahul    Finance           3  Head Office
# 3    Sneha      Sales           5  Head Office
# 4     Riya  Marketing           1  Head Office

# %%
# Question 19
#Replace the values in the Office column with numbers generated using np.arange(5).
from pandas import DataFrame
import numpy as np

data = {
    "Employee": ["Aman", "Priya", "Rahul", "Sneha", "Riya"],
    "Department": ["HR", "IT", "Finance", "Sales", "Marketing"],
    "Experience": [2, 4, 3, 5, 1]
}

employee_df = DataFrame(data)

employee_df["Office"] = "Head Office"

employee_df["Office"] = np.arange(5)

print(employee_df)
# Out:
#   Employee Department  Experience  Office
# 0     Aman         HR           2       0
# 1    Priya         IT           4       1
# 2    Rahul    Finance           3       2
# 3    Sneha      Sales           5       3
# 4     Riya  Marketing           1       4

# %%
# Question 20
#Create a Series named office_names containing 'Delhi', 'Mumbai', and 'Pune' at indexes 0, 2, and 4. Assign it to the Office column of employee_df and display the result.
from pandas import DataFrame, Series

data = {
    "Employee": ["Aman", "Priya", "Rahul", "Sneha", "Riya"],
    "Department": ["HR", "IT", "Finance", "Sales", "Marketing"],
    "Experience": [2, 4, 3, 5, 1]
}

employee_df = DataFrame(data)

office_names = Series(["Delhi", "Mumbai", "Pune"], index=[0, 2, 4])

employee_df["Office"] = office_names

print(employee_df)
# Out:
#   Employee Department  Experience  Office
# 0     Aman         HR           2   Delhi
# 1    Priya         IT           4     NaN
# 2    Rahul    Finance           3  Mumbai
# 3    Sneha      Sales           5     NaN
# 4     Riya  Marketing           1    Pune

# %%
# Question 21
#Delete the Office column from employee_df and display the remaining columns.
from pandas import DataFrame, Series

data = {
    "Employee": ["Aman", "Priya", "Rahul", "Sneha", "Riya"],
    "Department": ["HR", "IT", "Finance", "Sales", "Marketing"],
    "Experience": [2, 4, 3, 5, 1]
}

employee_df = DataFrame(data)

office_names = Series(["Delhi", "Mumbai", "Pune"], index=[0, 2, 4])

employee_df["Office"] = office_names

employee_df = employee_df.drop("Office", axis=1)

print(employee_df)
# Out:
#   Employee Department  Experience
# 0     Aman         HR           2
# 1    Priya         IT           4
# 2    Rahul    Finance           3
# 3    Sneha      Sales           5
# 4     Riya  Marketing           1

# %%
# Question 22
#Create a DataFrame named product_df from a dictionary containing Product, Category, and Price. Then construct another DataFrame with the columns ordered as Price, Product, Category.
from pandas import DataFrame

data = {
    "Product": ["Laptop", "Mobile", "Headphones", "Keyboard"],
    "Category": ["Electronics", "Electronics", "Accessories", "Accessories"],
    "Price": [50000, 20000, 3000, 1500]
}

product_df = DataFrame(data)

new_df = DataFrame(product_df, columns=["Price", "Product", "Category"])

print(new_df)
# Out:
#    Price     Product     Category
# 0  50000      Laptop  Electronics
# 1  20000      Mobile  Electronics
# 2   3000  Headphones  Accessories
# 3   1500    Keyboard  Accessories

# %%
# Question 23
#Construct a DataFrame from existing data while requesting four columns, where one of the requested columns does not exist in the source data. Display the resulting DataFrame and inspect what appears in the missing column.
from pandas import DataFrame

data = {
    "Product": ["Laptop", "Mobile", "Headphones", "Keyboard"],
    "Category": ["Electronics", "Electronics", "Accessories", "Accessories"],
    "Price": [50000, 20000, 3000, 1500]
}

product_df = DataFrame(data)

new_df = DataFrame(product_df, columns=["Product", "Category", "Price", "Brand"])

print(new_df)
# Out:
#       Product     Category  Price  Brand
# 0      Laptop  Electronics  50000    NaN
# 1      Mobile  Electronics  20000    NaN
# 2  Headphones  Accessories   3000    NaN
# 3    Keyboard  Accessories   1500    NaN

# %%
# Question 24
#Create a DataFrame with a column name containing a space, such as Total Marks. Retrieve that column using the appropriate column-selection syntax demonstrated in the notebook.
from pandas import DataFrame

data = {
    "Name": ["Aman", "Priya", "Rahul", "Sneha"],
    "Total Marks": [85, 90, 78, 92]
}

student_df = DataFrame(data)

# Retrieve the "Total Marks" column
print(student_df["Total Marks"])
# Out:
# 0    85
# 1    90
# 2    78
# 3    92
# Name: Total Marks, dtype: int64

# %%
# Question 25
#Read a copied table into a DataFrame using pd.read_clipboard(). Display its column names and then create a second DataFrame containing any three selected columns.
import pandas as pd

df = pd.read_clipboard()

print(df.columns)

df2 = df[['Column1', 'Column2', 'Column3']]

print(df2)
# Out:
# ---------------------------------------------------------------------------
# PyperclipException                        Traceback (most recent call last)
# /tmp/ipykernel_5003/2720641157.py in <cell line: 0>()
#       2 import pandas as pd
#       3
# ----> 4 df = pd.read_clipboard()
#       5
#       6 print(df.columns)
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/clipboards.py in read_clipboard(sep, dtype_backend, **kwargs)
#      84     from pandas.io.parsers import read_csv
#      85
# ---> 86     text = clipboard_get()
#      87
#      88     # Try to decode (if needed, as "text" might already be a string here).
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/clipboard/__init__.py in lazy_load_stub_paste()
#     679     global copy, paste
#     680     copy, paste = determine_clipboard()
# --> 681     return paste()
#     682
#     683
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/clipboard/__init__.py in __call__(self, *args, **kwargs)
# ...

# %%
# Question 26
#Create a five-row DataFrame named course_df with columns Student, Course, and Score. Then, in sequence: display its column names, retrieve Student, create a DataFrame containing Student and Score, and add a new column named Batch with the same value for all rows.
import pandas as pd

course_df = pd.DataFrame({
    "Student": ["Aman", "Priya", "Rahul", "Sneha", "Karan"],
    "Course": ["Python", "Java", "C++", "Data Science", "AI"],
    "Score": [85, 90, 78, 92, 88]
})

print(course_df.columns)

print(course_df["Student"])

student_score = course_df[["Student", "Score"]]
print(student_score)

course_df["Batch"] = "B1"

print(course_df)
# Out:
# Index(['Student', 'Course', 'Score'], dtype='object')
# 0     Aman
# 1    Priya
# 2    Rahul
# 3    Sneha
# 4    Karan
# Name: Student, dtype: object
#   Student  Score
# 0    Aman     85
# 1   Priya     90
# 2   Rahul     78
# 3   Sneha     92
# 4   Karan     88
#   Student        Course  Score Batch
# 0    Aman        Python     85    B1
# 1   Priya          Java     90    B1
# 2   Rahul           C++     78    B1
# 3   Sneha  Data Science     92    B1
# 4   Karan            AI     88    B1

# %%
# Question 27
#Create a five-row DataFrame named travel_df. Add a column named Code using np.arange(5). Next, replace that column with a Series containing values only at indexes 1 and 4. Display the DataFrame after each assignment.
import pandas as pd
import numpy as np

travel_df = pd.DataFrame({
    "Place": ["Delhi", "Agra", "Jaipur", "Goa", "Manali"],
    "Days": [3, 2, 4, 5, 6]
})

travel_df["Code"] = np.arange(5)
print(travel_df)

travel_df["Code"] = pd.Series({1: 100, 4: 500})
print(travel_df)
# Out:
#     Place  Days  Code
# 0   Delhi     3     0
# 1    Agra     2     1
# 2  Jaipur     4     2
# 3     Goa     5     3
# 4  Manali     6     4
#     Place  Days   Code
# 0   Delhi     3    NaN
# 1    Agra     2  100.0
# 2  Jaipur     4    NaN
# 3     Goa     5    NaN
# 4  Manali     6  500.0

# %%
# Question 28
#Create a DataFrame named school_df from a dictionary containing Student, Class, and Section. Construct a second DataFrame requesting the columns Student, Class, Section, and House, even though House is not present in the original data. Then assign one common value to the complete House column.
import pandas as pd

data = {
    "Student": ["Aman", "Priya", "Rahul", "Sneha", "Karan"],
    "Class": [10, 9, 10, 8, 9],
    "Section": ["A", "B", "A", "C", "B"]
}

school_df = pd.DataFrame(data)

school_df2 = pd.DataFrame(data, columns=["Student", "Class", "Section", "House"])

school_df2["House"] = "Red"

print(school_df2)
# Out:
#   Student  Class Section House
# 0    Aman     10       A   Red
# 1   Priya      9       B   Red
# 2   Rahul     10       A   Red
# 3   Sneha      8       C   Red
# 4   Karan      9       B   Red

# %%
# Question 29
#Create a DataFrame named inventory_df from equal-length lists. Add a new column using a partially indexed Series so that values appear only for selected row indexes. Display the result, then delete the added column and display the DataFrame again.
import pandas as pd

inventory_df = pd.DataFrame({
    "Item": ["Pen", "Pencil", "Eraser", "Scale", "Marker"],
    "Price": [10, 5, 8, 15, 20],
    "Stock": [100, 150, 80, 60, 40]
})

inventory_df["Discount"] = pd.Series({0: 5, 2: 10, 4: 15})
print(inventory_df)

del inventory_df["Discount"]
print(inventory_df)
# Out:
#      Item  Price  Stock  Discount
# 0     Pen     10    100       5.0
# 1  Pencil      5    150       NaN
# 2  Eraser      8     80      10.0
# 3   Scale     15     60       NaN
# 4  Marker     20     40      15.0
#      Item  Price  Stock
# 0     Pen     10    100
# 1  Pencil      5    150
# 2  Eraser      8     80
# 3   Scale     15     60
# 4  Marker     20     40

# %%
# Question 30
#Copy a table with at least four columns from any webpage or spreadsheet and read it into lab_df. Write one sequence of Pandas statements to: display the DataFrame, display its column names, retrieve one single-word column, retrieve one column whose name contains a space, construct a smaller DataFrame from selected columns, add a new whole column, and finally delete that column.
import pandas as pd

lab_df = pd.read_clipboard()

print(lab_df)

print(lab_df.columns)

print(lab_df["Name"])

print(lab_df["Total Marks"])

small_df = lab_df[["Name", "Age", "Total Marks"]]
print(small_df)

lab_df["Batch"] = "A"

print(lab_df)

del lab_df["Batch"]

print(lab_df)
# Out:
# ---------------------------------------------------------------------------
# PyperclipException                        Traceback (most recent call last)
# /tmp/ipykernel_5003/41854093.py in <cell line: 0>()
#       2 import pandas as pd
#       3
# ----> 4 lab_df = pd.read_clipboard()
#       5
#       6 print(lab_df)
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/clipboards.py in read_clipboard(sep, dtype_backend, **kwargs)
#      84     from pandas.io.parsers import read_csv
#      85
# ---> 86     text = clipboard_get()
#      87
#      88     # Try to decode (if needed, as "text" might already be a string here).
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/clipboard/__init__.py in lazy_load_stub_paste()
#     679     global copy, paste
#     680     copy, paste = determine_clipboard()
# --> 681     return paste()
#     682
#     683
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/clipboard/__init__.py in __call__(self, *args, **kwargs)
# ...
